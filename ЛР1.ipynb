# %%
import requests 
from bs4 import BeautifulSoup
#Список ссылок
links = [ 'https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%83%D1%80%D0%B3%D0%B8%D1%8F', 
        'https://ru.wikipedia.org/wiki/%D0%A7%D1%91%D1%80%D0%BD%D0%B0%D1%8F_%D0%BC%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%83%D1%80%D0%B3%D0%B8%D1%8F', 
        'https://ru.wikipedia.org/wiki/%D0%A6%D0%B2%D0%B5%D1%82%D0%BD%D0%B0%D1%8F_%D0%BC%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%83%D1%80%D0%B3%D0%B8%D1%8F',
        'https://ru.wikipedia.org/wiki/%D0%94%D0%BE%D0%BC%D0%B5%D0%BD%D0%BD%D0%B0%D1%8F_%D0%BF%D0%B5%D1%87%D1%8C', 
        'https://ru.wikipedia.org/wiki/%D0%A1%D1%82%D0%B0%D0%BB%D1%8C', 
        'https://ru.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%BA%D0%B0%D1%82', 
        'https://ru.wikipedia.org/wiki/%D0%A6%D0%B5%D0%BD%D1%82%D1%80%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D0%BC%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%83%D1%80%D0%B3%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D0%B1%D0%B0%D0%B7%D0%B0', 
        'https://ru.wikipedia.org/wiki/%D0%A1%D0%B8%D0%B1%D0%B8%D1%80%D1%81%D0%BA%D0%B0%D1%8F_%D0%BC%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%83%D1%80%D0%B3%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D0%B1%D0%B0%D0%B7%D0%B0', 
        'https://ru.wikipedia.org/wiki/%D0%A7%D1%91%D1%80%D0%BD%D1%8B%D0%B5_%D0%BC%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%8B', 
        'https://ru.wikipedia.org/wiki/%D0%9E%D0%B3%D0%BD%D0%B5%D1%83%D0%BF%D0%BE%D1%80%D0%BD%D1%8B%D0%B5_%D0%BC%D0%B0%D1%82%D0%B5%D1%80%D0%B8%D0%B0%D0%BB%D1%8B', 
        'https://ru.wikipedia.org/wiki/%D0%9E%D0%BA%D1%83%D1%81%D0%BA%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5', 
        'https://ru.wikipedia.org/wiki/%D0%A7%D1%83%D0%B3%D1%83%D0%BD', 
        'https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D0%BA%D1%81%D0%BE%D1%85%D0%B8%D0%BC%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D0%BF%D1%80%D0%BE%D0%BC%D1%8B%D1%88%D0%BB%D0%B5%D0%BD%D0%BD%D0%BE%D1%81%D1%82%D1%8C', 
        'https://ru.wikipedia.org/wiki/%D0%A2%D1%8F%D0%B6%D1%91%D0%BB%D1%8B%D0%B5_%D0%BC%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%8B', 
        'http://metall4all.ru/info/gruppi-metallov/legkie-metally/' ]
#Словарь для хранения ресурса и ключевых терминов
resources = {}
#Обход каждой ссылки
for link in links: 
    # Получение HTML-кода страницы по ссылке 
    response = requests.get(link) 
    soup = BeautifulSoup(response.text, 'html.parser')
    # Получение заголовка страницы 
    title = soup.find('title').text
    # Получение ключевых терминов 
    keywords = []
    metatags = soup.find_all('meta', attrs={'name': 'keywords'}) 
    for metatag in metatags: 
        keyword = metatag['content'] 
        keywords.extend(keyword.split(','))

        # Сохранение ресурса и ключевых терминов в словаре 
    resources[title] = keywords

#Вывод результатов
for resource, keywords in resources.items(): 
        print(resource) 
        print('-' * len(resource)) 
        print('Ключевые термины:') 
        for keyword in keywords: 
                print(keyword) 
        print()



from graphviz import Digraph

# Создание графа
dot = Digraph(comment='Metallurgy')

# Добавление узлов
for resource in resources:
    dot.node(resource)

# Добавление связей
for resource, keywords in resources.items():
    for keyword in keywords:
        dot.edge(resource, keyword)

# Вывод графа
dot.render('metallurgy_graph', view=True)
# Out:
# Металлургия — Википедия
# -----------------------
# Ключевые термины:
#
# Чёрная металлургия — Википедия
# ------------------------------
# Ключевые термины:
#
# Цветная металлургия — Википедия
# -------------------------------
# Ключевые термины:
#
# Доменная печь — Википедия
# -------------------------
# Ключевые термины:
#
# Сталь — Википедия
# -----------------
# Ключевые термины:
#
# Прокат — Википедия
# ------------------
# Ключевые термины:
#
# Центральная металлургическая база — Википедия
# ---------------------------------------------
# Ключевые термины:
#
# Сибирская металлургическая база — Википедия
# -------------------------------------------
# Ключевые термины:
#
# Чёрные металлы — Википедия
# --------------------------
# Ключевые термины:
#
# Огнеупорные материалы — Википедия
# ---------------------------------
# Ключевые термины:
#
# Окускование — Википедия
# -----------------------
# Ключевые термины:
#
# Чугун — Википедия
# -----------------
# Ключевые термины:
#
# ...
